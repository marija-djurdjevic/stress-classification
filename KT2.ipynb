# %% [markdown]
# <a href="https://colab.research.google.com/github/marija-djurdjevic/stress-classification/blob/main/KT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content
